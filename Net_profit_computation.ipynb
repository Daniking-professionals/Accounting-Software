# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniking-professionals/Accounting-Software/blob/main/Net_profit_computation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Computation of Net profit in a year
total_revenue = 250000000 # initial total revenue in million naira
revenue_rata = 1.07 # 7% annual revenue growth rate
total_expenses = 130000000 # initial total expenses in million naira
expenses_growth_rate = 1.05 # 5% annual expenses growth rate
yearn = 0
while total_revenue < 300000000
while total_expenses < 150000000
total_revemue *= revenue_growth_rate
total_expenses *= expenses_growth_rate
year += 1
net_profit == total_revenue - total_expenses
print("Net Profit for the Year: {"net_profit"}")
